# %% [markdown]
# <a href="https://colab.research.google.com/github/philips456/symfo/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📥 1. Chargement des données

# %%
import pandas as pd

# Charger le fichier CSV
df = pd.read_csv("/content/mm-5G.csv")

# Afficher les 5 premières lignes
print(df.head())
# Out:
#    run_num  seq_num  abstractSignalStr   latitude  longitude  movingSpeed  \
# 0        1      1.0                  2  44.975314 -93.259316     0.094889
# 1        1      2.0                  2  44.975311 -93.259311     0.876634
# 2        1      3.0                  2  44.975305 -93.259292     2.225798
# 3        1      4.0                  2  44.975293 -93.259258     3.180726
# 4        1      5.0                  2  44.975278 -93.259214     3.751234
#
#    compassDirection        nrStatus  lte_rssi  lte_rsrp  lte_rsrq  \
# 0               150  NOT_RESTRICTED     -61.0       -94     -14.0
# 1               117  NOT_RESTRICTED     -61.0       -94     -14.0
# 2               113  NOT_RESTRICTED     -61.0       -94     -14.0
# 3               114  NOT_RESTRICTED     -59.0       -95     -16.0
# 4               115  NOT_RESTRICTED     -59.0       -95     -16.0
#
#       lte_rssnr  nr_ssRsrp  nr_ssRsrq  nr_ssSinr  Throughput mobility_mode  \
# ...

# %% [markdown]
# 🔍 2. Aperçu général du dataset

# %%
# Afficher les informations générales
print(df.info())

# Afficher les statistiques générales des variables numériques
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68118 entries, 0 to 68117
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   run_num               68118 non-null  int64
#  1   seq_num               68118 non-null  float64
#  2   abstractSignalStr     68118 non-null  int64
#  3   latitude              68118 non-null  float64
#  4   longitude             68118 non-null  float64
#  5   movingSpeed           68118 non-null  float64
#  6   compassDirection      68118 non-null  int64
#  7   nrStatus              68118 non-null  object
#  8   lte_rssi              65137 non-null  float64
#  9   lte_rsrp              68118 non-null  int64
#  10  lte_rsrq              65137 non-null  float64
#  11  lte_rssnr             65137 non-null  float64
#  12  nr_ssRsrp             51990 non-null  float64
#  13  nr_ssRsrq             51990 non-null  float64
# ...

# %% [markdown]
# Histogramme du débit (Throughput) :

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df["Throughput"], bins=30, kde=True, color="royalblue")
plt.xlabel("Débit (Mbps)")
plt.ylabel("Fréquence")
plt.title("Distribution du Débit (Throughput)")
plt.show()

# %% [markdown]
# 2️⃣ Boxplots pour détecter les valeurs extrêmes des indicateurs de signal

# %%
signal_vars = ["lte_rsrp", "lte_rsrq", "nr_ssRsrp", "nr_ssRsrq", "lte_rssnr", "nr_ssSinr"]

plt.figure(figsize=(12, 6))
sns.boxplot(data=df[signal_vars])
plt.xticks(rotation=15)
plt.title("Boxplot des indicateurs de qualité du signal")
plt.show()

# %% [markdown]
# 3️⃣ Heatmap (Carte de corrélation)

# %%
# Sélectionner uniquement les colonnes numériques
df_numeric = df.select_dtypes(include=['number'])

# Générer la heatmap avec uniquement les variables numériques
plt.figure(figsize=(10, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Carte de Corrélation entre les Variables")
plt.show()

# %% [markdown]
# 4️⃣ Effet de la vitesse du mobile sur la connexion

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df["movingSpeed"], y=df["Throughput"], alpha=0.7, color="darkgreen")
plt.xlabel("Vitesse du Mobile (km/h)")
plt.ylabel("Débit (Mbps)")
plt.title("Impact de la Vitesse du Mobile sur le Débit")
plt.show()
